# %% [markdown]
# <a href="https://colab.research.google.com/github/juanfranciscog/Coursera---Data-Analysis/blob/master/2023_04_08_CIS5450_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIT 5450 Final Project
# Joanne Crean, Juan Goleniowski, Joseph Ricci

# %% [markdown]
# Before running, be sure to create a new Kaggle API token and save it as 'kaggle.json' in your default Google Drive location (/content/drive/MyDrive/)

# %%
# Installs
# !pip install -q kaggle

#test

# %%
# Imports
import pandas as pd
from google.colab import drive
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Setup
drive.mount('/content/drive')
# !mkdir ~/.kaggle
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/
# Out:
# Mounted at /content/drive

# %%
# Download Datasets
# Spotify Top 200 and Viral 50 Charts for 2017 through 2021 Dataset
# !!kaggle datasets download -d dhruvildave/spotify-charts

# Spotify Audio Features Datasets
# !!kaggle datasets download -d rodolfofigueroa/spotify-12m-songs
# !!kaggle datasets download -d muhmores/spotify-top-100-songs-of-20152019
# !!kaggle datasets download -d sashankpillai/spotify-top-200-charts-20202021
# !!kaggle datasets download -d maharshipandya/-spotify-tracks-dataset
# !!kaggle datasets download -d vatsalmavani/spotify-dataset
# !!kaggle datasets download -d nandhakumarss/spotify-song-tracks
# !!kaggle datasets download -d elemento/music-albums-popularity-prediction

# TikTok Popular Songs Dataset
# !!kaggle datasets download -d sveta151/tiktok-popular-songs-2019
# !!kaggle datasets download -d sveta151/tiktok-popular-songs-2020
# !!kaggle datasets download -d sveta151/tiktok-popular-songs-2021
# Out:
# ['Downloading tiktok-popular-songs-2021.zip to /content',
#  '',
#  '  0% 0.00/11.0k [00:00<?, ?B/s]',
#  '',
#  '100% 11.0k/11.0k [00:00<00:00, 9.05MB/s]']

# %%
# Unzip Datasets
# !unzip /content/spotify-charts.zip
# !unzip /content/spotify-12m-songs.zip
# !unzip /content/spotify-top-100-songs-of-20152019.zip
# !unzip /content/spotify-top-200-charts-20202021.zip
# !unzip /content/-spotify-tracks-dataset.zip
# !unzip /content/spotify-dataset.zip
# !unzip /content/spotify-song-tracks.zip
# !unzip /content/music-albums-popularity-prediction.zip
# !unzip /content/tiktok-popular-songs-2019
# !unzip /content/tiktok-popular-songs-2020
# !unzip /content/tiktok-popular-songs-2021
# Out:
# Archive:  /content/spotify-charts.zip
#   inflating: charts.csv
# Archive:  /content/spotify-12m-songs.zip
#   inflating: tracks_features.csv
# Archive:  /content/spotify-top-100-songs-of-20152019.zip
#   inflating: Spotify 2010 - 2019 Top 100 Songs.xlsx
#   inflating: Spotify 2010 - 2019 Top 100.csv
# Archive:  /content/spotify-top-200-charts-20202021.zip
#   inflating: spotify_dataset.csv
# Archive:  /content/-spotify-tracks-dataset.zip
#   inflating: dataset.csv
# Archive:  /content/spotify-dataset.zip
#   inflating: data/data.csv
#   inflating: data/data_by_artist.csv
#   inflating: data/data_by_genres.csv
#   inflating: data/data_by_year.csv
#   inflating: data/data_w_genres.csv
# Archive:  /content/spotify-song-tracks.zip
#   inflating: SpotifyFeatures.csv
# Archive:  /content/music-albums-popularity-prediction.zip
#   inflating: sample_solution.csv
#   inflating: test.csv
#   inflating: train.csv
# Archive:  /content/tiktok-popular-songs-2019.zip
#   inflating: TikTok_songs_2019.csv
#   inflating: TikTok_songs_2019.xlsx
# Archive:  /content/tiktok-popular-songs-2020.zip
#   inflating: TikTok_songs_2020.csv
# Archive:  /content/tiktok-popular-songs-2021.zip
#   inflating: TikTok_songs_2021.csv

# %%
# Clean up directory to save space
# !rm sample_data/*
# !rm -d sample_data
# !rm ./*.zip
# !rm sample_solution.csv
# !rm ./*.xlsx

# %%
# Read the csv files and save them to pandas dataframes
df_charts = pd.read_csv('charts.csv')
df_song_features_1 = pd.read_csv('tracks_features.csv')
df_song_features_2 = pd.read_csv('Spotify 2010 - 2019 Top 100.csv')
df_song_features_3 = pd.read_csv('spotify_dataset.csv')
df_song_features_4 = pd.read_csv('dataset.csv')
df_song_features_5 = pd.read_csv('data/data.csv')
df_song_features_6 = pd.read_csv('SpotifyFeatures.csv')
df_song_features_7 = pd.read_csv('train.csv')
df_song_features_10 = pd.read_csv('test.csv')
df_tiktok_19 = pd.read_csv('TikTok_songs_2019.csv')
df_tiktok_20 = pd.read_csv('TikTok_songs_2020.csv')
df_tiktok_21 = pd.read_csv('TikTok_songs_2021.csv')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Clean up remaining files
# !rm data/*
# !rm -d data
# !rm ./*.csv

# %% [markdown]
# # Spotify Top 200 and Viral 50 Charts EDA

# %%
# Create a separate column for Year
df_charts['Year']=df_charts['date'].str.slice(stop=4)

# Cast 'Year' as Int
df_charts['Year'] = df_charts['Year'].astype(int)

# Show datatypes 
df_charts.dtypes

#remove ID, trend and streams columns
df_charts.drop(['url', 'trend', 'streams'], axis=1, inplace=True)

# %%
# Number of record per year
df_charts.groupby(by='Year').count()
# Out:
#         title     rank     date   artist   region    chart
# Year
# 2017  4401145  4401145  4401145  4401145  4401145  4401145
# 2018  4863016  4863016  4863016  4863016  4863016  4863016
# 2019  5412658  5412669  5412669  5412669  5412669  5412669
# 2020  5793148  5793148  5793148  5793130  5793148  5793148
# 2021  5703536  5703536  5703536  5703536  5703536  5703536

# %%
# Remore records with year 2017 and 2018
df_charts=df_charts[df_charts['Year'] > 2018]

# %%
df_charts.groupby(by='Year').count()
# Out:
#         title     rank     date   artist   region    chart
# Year
# 2019  5412658  5412669  5412669  5412669  5412669  5412669
# 2020  5793148  5793148  5793148  5793130  5793148  5793148
# 2021  5703536  5703536  5703536  5703536  5703536  5703536

# %% [markdown]
# # Spotify Audio Feature Dataset EDA
#
# Since the Spotify Top 200 and Viral 50 charts dataset does not come with audio features the songs, there is no guarantee that we can find datasets that include audio features for all of the songs in the charts. One relevant question to explore is therefore
#
# 1. Can we find audio feature data for a suitably "big" fraction of the songs in the Charts dataset?
#
# Additionally, since we'll be combining multiple audio features datasets, there is no guarantee that those datasets share the same features, so
#
# 2. What fields do the datasets share?

# %%
# First, since we want to find song features for as many of the songs in 'df_charts' as possible, let's start by
# projecting df_charts by song title and artist name, which will uniquely identify each song, and then dropping duplicates
df_charts_songs_artists = df_charts[['title', 'artist']].drop_duplicates()

# Next, let's join the features datasets on song title and artist name and see what percentage of songs in charts_df
# each song features dataset can provide features for

# Clean extranneous characters from artist columns if necessary
df_song_features_1['artists'] = df_song_features_1['artists'].str.replace('[', '').str.replace(']', '').str.replace("'", '')
df_song_features_5['artists'] = df_song_features_5['artists'].str.replace('[', '').str.replace(']', '').str.replace("'", '')
df_song_features_7['artists'] = df_song_features_7['artists'].str.replace(', ', '')
df_song_features_10['artists'] = df_song_features_10['artists'].str.replace(', ', '')

# Project only the necessary columns from each feature dataset and also rename to maintain consistency
features_1_projected = df_song_features_1[['name', 'artists']].rename(columns={'name': 'title', 'artists': 'artist'})
features_2_projected = df_song_features_2[['title', 'artist']]
features_3_projected = df_song_features_3[['Song Name', 'Artist']].rename(columns={'Song Name': 'title', 'Artist': 'artist'})
features_4_projected = df_song_features_4[['track_name', 'artists']].rename(columns={'track_name': 'title', 'artists': 'artist'})
features_5_projected = df_song_features_5[['name', 'artists']].rename(columns={'name': 'title', 'artists': 'artist'})
features_6_projected = df_song_features_6[['track_name', 'artist_name']].rename(columns={'track_name': 'title', 'artist_name': 'artist'})
features_7_projected = df_song_features_7[['t_name0', 'artists']].rename(columns={'t_name0': 'title', 'artists': 'artist'})
features_8_projected = df_song_features_7[['t_name1', 'artists']].rename(columns={'t_name1': 'title', 'artists': 'artist'})
features_9_projected = df_song_features_7[['t_name2', 'artists']].rename(columns={'t_name2': 'title', 'artists': 'artist'})
features_10_projected = df_song_features_10[['t_name0', 'artists']].rename(columns={'t_name0': 'title', 'artists': 'artist'})
features_11_projected = df_song_features_10[['t_name1', 'artists']].rename(columns={'t_name1': 'title', 'artists': 'artist'})
features_12_projected = df_song_features_10[['t_name2', 'artists']].rename(columns={'t_name2': 'title', 'artists': 'artist'})

# Join on song title and artist name
merge_1 = pd.merge(df_charts_songs_artists, features_1_projected, on=['title', 'artist'], how='inner').drop_duplicates()
merge_2 = pd.merge(df_charts_songs_artists, features_2_projected, on=['title', 'artist'], how='inner').drop_duplicates()
merge_3 = pd.merge(df_charts_songs_artists, features_3_projected, on=['title', 'artist'], how='inner').drop_duplicates()
merge_4 = pd.merge(df_charts_songs_artists, features_4_projected, on=['title', 'artist'], how='inner').drop_duplicates()
merge_5 = pd.merge(df_charts_songs_artists, features_5_projected, on=['title', 'artist'], how='inner').drop_duplicates()
merge_6 = pd.merge(df_charts_songs_artists, features_6_projected, on=['title', 'artist'], how='inner').drop_duplicates()
merge_7 = pd.merge(df_charts_songs_artists, features_7_projected, on=['title', 'artist'], how='inner').drop_duplicates()
merge_8 = pd.merge(df_charts_songs_artists, features_8_projected, on=['title', 'artist'], how='inner').drop_duplicates()
merge_9 = pd.merge(df_charts_songs_artists, features_9_projected, on=['title', 'artist'], how='inner').drop_duplicates()
merge_10 = pd.merge(df_charts_songs_artists, features_10_projected, on=['title', 'artist'], how='inner').drop_duplicates()
merge_11 = pd.merge(df_charts_songs_artists, features_11_projected, on=['title', 'artist'], how='inner').drop_duplicates()
merge_12 = pd.merge(df_charts_songs_artists, features_12_projected, on=['title', 'artist'], how='inner').drop_duplicates()

# Calculate the percentage of songs each features dataset was able to provide song features for
df_combined_features = pd.concat([merge_1, merge_2, merge_3, merge_4, merge_5, merge_6, merge_7, merge_8, merge_9, merge_10, merge_11, merge_12], ignore_index=True).drop_duplicates()
match_percentage_combined = 100 * df_combined_features.shape[0] / df_charts_songs_artists.shape[0]
print("We are able to provide audio features for " + str(round(match_percentage_combined,2)) + "% of songs in df_charts,"\
      " for a total of " + str(df_combined_features.shape[0]) + " out of " + str(df_charts_songs_artists.shape[0]) + " songs")
# Out:
# We are able to provide audio features for 16.48% of songs in df_charts, for a total of 18950 out of 115016 songs

# %%
df_combined_features.head()
# Out:
#        title     artist
# 0    Ride It     Regard
# 1       25/8  Bad Bunny
# 2       Keii   Anuel AA
# 3  Hei rakas       BEHM
# 4      GOOBA    6ix9ine

# %% [markdown]
# # TikTok Popular Songs Dataset EDA

# %%
df_tiktok_19.head()
# Out:
#              track_name                 artist_name  artist_pop  \
# 0              Shake It               Metro Station          53
# 1      Chinese New Year                       SALES          61
# 2        Baby I'm Yours                    Breakbot          57
# 3            The Git Up                Blanco Brown          60
# 4  Say Hey (I Love You)  Michael Franti & Spearhead          58
#
#                album  track_pop  danceability  energy  loudness  mode  key  \
# 0      Metro Station         68         0.618   0.955    -3.836     1    4
# 1         SALES - EP         53         0.744   0.845    -7.422     0    4
# 2       By Your Side         69         0.829   0.792    -3.755     0    2
# 3         The Git Up          2         0.847   0.678    -8.635     1    9
# 4  All Rebel Rockers          0         0.738   0.983    -4.374     0    5
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.0798       0.00221          0.000003     0.486    0.790  150.034
# 1       0.2530       0.75900          0.232000     0.100    0.749   75.221
# 2       0.0668       0.72600          0.000006     0.122    0.758  118.050
# 3       0.1090       0.06690          0.000000     0.274    0.811   97.984
# 4       0.0855       0.03800          0.000006     0.183    0.957   92.998
#
#    time_signature  duration_ms
# 0               4       179947
# 1               4       160000
# 2               4       215507
# 3               4       200594
# 4               4       235760

# %%
df_tiktok_20.head()
# Out:
#                          track_name          artist_name  artist_pop  \
# 0                            Say So             Doja Cat          88
# 1                   Blinding Lights           The Weeknd          93
# 2  Supalonely (feat. Gus Dapperton)                BENEE          67
# 3                            Savage  Megan Thee Stallion          82
# 4                Moral of the Story                 Ashe          68
#
#                 album  track_pop  danceability  energy  loudness  mode  key  \
# 0            Hot Pink         80         0.787   0.673    -4.583     0   11
# 1         After Hours         90         0.514   0.730    -5.934     1    1
# 2             Hey u x         63         0.862   0.631    -4.746     1    7
# 3                Suga         70         0.843   0.741    -5.609     1   11
# 4  Moral of the Story         76         0.572   0.406    -8.624     1   10
#
#    speechiness  acousticness  instrumentalness  liveness  valence    tempo  \
# 0       0.1590       0.26400          0.000003    0.0904    0.779  110.962
# 1       0.0598       0.00146          0.000095    0.0897    0.334  171.005
# 2       0.0515       0.29100          0.000209    0.1230    0.841  128.978
# 3       0.3340       0.02520          0.000000    0.0960    0.680  168.983
# 4       0.0427       0.58700          0.000004    0.1020    0.265  119.812
#
#    time_signature  duration_ms
# 0               4       237893
# 1               4       200040
# 2               4       223488
# 3               4       155497
# 4               4       201084

# %%
df_tiktok_21.head()
# Out:
#                                track_name    artist_name  artist_pop  \
# 0               STAY (with Justin Bieber)  The Kid LAROI          83
# 1  Peaches (feat. Daniel Caesar & Giveon)  Justin Bieber          90
# 2              edamame (feat. Rich Brian)          bbno$          72
# 3                     Here's Your Perfect   Jamie Miller          65
# 4                                It's You        Sezairi          57
#
#                         album  track_pop  danceability  energy  loudness  \
# 0   STAY (with Justin Bieber)         89         0.591   0.764    -5.484
# 1                     Justice         86         0.677   0.696    -6.181
# 2  edamame (feat. Rich Brian)         77         0.815   0.848    -4.704
# 3         Here's Your Perfect         77         0.558   0.454    -5.335
# 4                    It's You         73         0.630   0.456    -8.285
#
#    mode  key  speechiness  acousticness  instrumentalness  liveness  valence  \
# 0     1    1       0.0483        0.0383          0.000000    0.1030    0.478
# 1     1    0       0.1190        0.3210          0.000000    0.4200    0.464
# 2     0    4       0.1150        0.0230          0.000162    0.0265    0.684
# 3     1    6       0.0551        0.4990          0.000000    0.1460    0.424
# 4     1    8       0.0317        0.5450          0.000000    0.1140    0.166
#
#      tempo  time_signature  duration_ms
# 0  169.928               4       141806
# 1   90.030               4       198082
# 2  106.032               4       133707
# 3  113.120               4       158594
# 4  137.915               3       251440

# %%
# Combine the tiktok datasets
data_tiktok = [df_tiktok_19, df_tiktok_20, df_tiktok_21]
df_tiktok_full = pd.concat(data_tiktok)

# %%
# Extract the track name and artist to check for the overlap
df_tiktok_tracks = df_tiktok_full[['track_name', 'artist_name']]

# Check number of rows
df_tiktok_tracks.shape[0]
# Out:
# 705

# %%
# Merge with spotify features on track names only to check overlap
df_tiktok_tracks_only = df_combined_features.merge(df_tiktok_tracks.drop_duplicates(), left_on = ['title'], right_on=['track_name'], how='inner')

# Check overlap
df_tiktok_tracks_only.shape[0]
# Out:
# 601

# %%
# Review rows that didn't match to see if there's more clean-up that can be done 
df_tiktok_full_merge = df_combined_features.merge(df_tiktok_tracks.drop_duplicates(), left_on = ['title'], right_on=['track_name'], how='outer', indicator = True)

# %%
df_tiktok_full_merge.head()
# Out:
#        title     artist track_name artist_name     _merge
# 0    Ride It     Regard    Ride It      Regard       both
# 1       25/8  Bad Bunny        NaN         NaN  left_only
# 2       Keii   Anuel AA        NaN         NaN  left_only
# 3  Hei rakas       BEHM        NaN         NaN  left_only
# 4      GOOBA    6ix9ine      GOOBA     6ix9ine       both

# %%
# Review rows that didn't match to see if there's more clean-up that can be done 
print(df_tiktok_full_merge[df_tiktok_full_merge['_merge'] != 'both'])
# Out:
#             title        artist                              track_name  \
# 1            25/8     Bad Bunny                                     NaN
# 2            Keii      Anuel AA                                     NaN
# 3       Hei rakas          BEHM                                     NaN
# 5              P2  Lil Uzi Vert                                     NaN
# 6      Siren Song         MARUV                                     NaN
# ...           ...           ...                                     ...
# 19160         NaN           NaN                           Favorite Girl
# 19161         NaN           NaN  Love Tonight - David Guetta Remix Edit
# 19162         NaN           NaN                           Polaroid Love
# 19163         NaN           NaN                                   Panda
# 19164         NaN           NaN                             TO THE MOON
#
#          artist_name      _merge
# 1                NaN   left_only
# 2                NaN   left_only
# 3                NaN   left_only
# 5                NaN   left_only
# 6                NaN   left_only
# ...              ...         ...
# 19160  Justin Bieber  right_only
# 19161         Shouse  right_only
# 19162        ENHYPEN  right_only
# 19163      Desiigner  right_only
# 19164       Jnr Choi  right_only
#
# [18564 rows x 5 columns]

# %%
# do a check to see if I convert the track names to lower case, could I get more matches 
df_tiktok_full_merge.dropna(inplace = True)
df_tiktok_full_merge['title_l'] = df_tiktok_full_merge.apply(lambda x : x['title'].lower(), axis =1)
df_tiktok_full_merge['track_name_l'] = df_tiktok_full_merge.apply(lambda x : x['track_name'].lower(), axis =1)

print(df_tiktok_full_merge[(df_tiktok_full_merge['title_l'] == df_tiktok_full_merge['track_name_l']) & (df_tiktok_full_merge['_merge'] != 'both')])

# prints an empty dataframe so the conclusion is that no I can't
# Out:
# Empty DataFrame
# Columns: [title, artist, track_name, artist_name, _merge, title_l, track_name_l]
# Index: []

# %%
# Create a match column to indicate cases where the tiktok artist name can be found as a substring in the spotify artist column 
df_tiktok_tracks_only['match'] = df_tiktok_tracks_only.apply(lambda x: x['artist_name'].lower().find(x['artist'].lower()), axis=1).ge(0)

# Create a match column to indicate cases where the spotify artist column can be found as a substring in the tiktok artist name 
df_tiktok_tracks_only['match_2'] = df_tiktok_tracks_only.apply(lambda x: x['artist'].lower().find(x['artist_name'].lower()), axis=1).ge(0)

# %%
# review data to see which rows have matched
print(df_tiktok_tracks_only[df_tiktok_tracks_only['match'] |df_tiktok_tracks_only['match_2']])
# Out:
#                                               title              artist  \
# 0                                           Ride It              Regard
# 1                                           Ride It              Regard
# 2                                             GOOBA             6ix9ine
# 3                                   Don't Start Now            Dua Lipa
# 4                                              Tutu  Camilo, Pedro Capó
# ..                                              ...                 ...
# 668                                       Aesthetic                Xilo
# 669                        love nwantiti (ah ah ah)                CKay
# 670  It Won't Stop (feat. Chris Brown) - EP Version      Sevyn Streeter
# 671                   STUPID (feat. Yung Baby Tate)            Ashnikko
# 672                                Every Summertime                NIKI
#
#                                          track_name     artist_name  match  \
# 0                                           Ride It          Regard   True
# 1                                           Ride It          Regard   True
# 2                                             GOOBA         6ix9ine   True
# 3                                   Don't Start Now        Dua Lipa   True
# 4                                              Tutu          Camilo  False
# ..                                              ...             ...    ...
# 668                                       Aesthetic            Xilo   True
# 669                        love nwantiti (ah ah ah)            CKay   True
# 670  It Won't Stop (feat. Chris Brown) - EP Version  Sevyn Streeter   True
# 671                   STUPID (feat. Yung Baby Tate)        Ashnikko   True
# 672                                Every Summertime            NIKI   True
#
#      match_2
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
# ..       ...
# 668     True
# 669     True
# 670     True
# 671     True
# 672     True
#
# [473 rows x 6 columns]

# %%
# review data to see which rows have not matched
print(df_tiktok_tracks_only[(df_tiktok_tracks_only['match'] == False) & (df_tiktok_tracks_only['match_2'] == False)])
# Out:
#                  title                                   artist  \
# 5                 Tutu                              Grupo Sigma
# 11              Say So  Poorchoice, Cam Sanders, Veronica Bravo
# 12              Say So  Poorchoice, Cam Sanders, Veronica Bravo
# 13              Say So  Poorchoice, Cam Sanders, Veronica Bravo
# 14              Say So                              Masked Wolf
# ..                 ...                                      ...
# 576            Asshole                              Denis Leary
# 615          Dangerous                                  Roxette
# 617       Good Morning                             Trippie Redd
# 638  When She Loved Me                          Sarah McLachlan
# 651  You Don't Know Me                              Peter Manos
#
#             track_name         artist_name  match  match_2
# 5                 Tutu              Camilo  False    False
# 11              Say So            Doja Cat  False    False
# 12              Say So            Doja Cat  False    False
# 13              Say So            Doja Cat  False    False
# 14              Say So            Doja Cat  False    False
# ..                 ...                 ...    ...      ...
# 576            Asshole      hooligan chase  False    False
# 615          Dangerous  Kardinal Offishall  False    False
# 617       Good Morning           Mak Sauce  False    False
# 638  When She Loved Me           Lyn Lapid  False    False
# 651  You Don't Know Me           Jax Jones  False    False
#
# [200 rows x 6 columns]

# %%
# check the rows where the artists names aren't an exact match - for visual inspection 
df_tiktok_tracks_only.loc[(df_tiktok_tracks_only['artist'] != df_tiktok_tracks_only['artist_name']) & (df_tiktok_tracks_only['match'] |df_tiktok_tracks_only['match_2'])]
# Out:
#                                                  title  \
# 4                                                 Tutu
# 6                     death bed (coffee for your head)
# 41                                  Deep End Freestyle
# 57                                              Lalala
# 58                                              Lalala
# 72                                            Go Crazy
# 113                   Savage Love (Laxed - Siren Beat)
# 114                   Savage Love (Laxed - Siren Beat)
# 166                                              Rodeo
# 171                                             Indigo
# 175                                 Never Ending Story
# 181                                              Juicy
# 217                                         Trampoline
# 233                                 Bored In The House
# 266                                            Bad Boy
# 277                                               Coño
# 286                                               Baby
# 314                                             Let Go
# 374                       Savage Remix (feat. Beyoncé)
# 376                                       Lose Control
# 389                        OUT WEST (feat. Young Thug)
# 390   Go Stupid (feat. NLE Choppa & Mike WiLL Made-It)
# 402                       Somebody That I Used To Know
# 419                                          You Right
# 444                                Leave The Door Open
# 445                                           Rasputin
# 450                                   Calling My Phone
# 461                                        Money Trees
# 467                                           Lemonade
# 533                                      We Found Love
# 542                                       American Boy
# 543                                       American Boy
# 544                                             No Lie
# 548                                             Middle
# 549                                    What's My Name?
# 552                                            Dilemma
# 557                                            Love Me
# 564                                        Do It Again
# 571                                        Griztronics
# 577                                      Falling for U
# 579                Fly Me To The Moon (In Other Words)
# 581                        The Muffin Song (asdfmovie)
# 587                                            Fake ID
# 588                                          Womp Womp
# 589                                       Un Poco Loco
# 593                                     Tunnel of Love
# 603                                            Big Fun
# 604                                       3 Musketeers
# 607                       Never Ever Getting Rid of Me
# 608                             Se Acabó la Cuarentena
# 609                                           La La La
# 614                                          Dangerous
# 620                                          Like A G6
# 625                                             Hello?
# 627  Sofia the First Main Title Theme - From "Sofia...
#
#                                                 artist  \
# 4                                   Camilo, Pedro Capó
# 6                                   Powfu, beabadoobee
# 41                              Sleepy Hallow, Fousheé
# 57                                          Y2K, bbno$
# 58                                          Y2K, bbno$
# 72                             Chris Brown, Young Thug
# 113                            Jawsh 685, Jason Derulo
# 114                            Jawsh 685, Jason Derulo
# 166                                 Lil Nas X, Cardi B
# 171                                     88rising, NIKI
# 175                 Gaten Matarazzo, Gabriella Pizzolo
# 181                                     Doja Cat, Tyga
# 217                                        SHAED, ZAYN
# 233                                 Tyga, Curtis Roach
# 266                 Yung Bae, bbno$, Billy Marchiafava
# 277                  Jason Derulo, Puri, Jhorrmountain
# 286                            Justin Bieber, Ludacris
# 314                          Ark Patrol, Veronika Redd
# 374                       Beyoncé, Megan Thee Stallion
# 376                       MEDUZA, Becky Hill, Goodboys
# 389                             JACKBOYS, Travis Scott
# 390                             Polo G, Stunna 4 Vegas
# 402                                      Gotye, Kimbra
# 419                               Doja Cat, The Weeknd
# 444             Bruno Mars, Anderson .Paak, Silk Sonic
# 445                                 Majestic, Boney M.
# 450                                    Lil Tjay, 6LACK
# 461                           Kendrick Lamar, Jay Rock
# 467            Internet Money, Gunna, Don Toliver, NAV
# 533                             Rihanna, Calvin Harris
# 542                                Estelle, Kanye West
# 543                                Estelle, Kanye West
# 544                                Sean Paul, Dua Lipa
# 548                         DJ Snake, Bipolar Sunshine
# 549                                     Rihanna, Drake
# 552                               Nelly, Kelly Rowland
# 557                           Lil Wayne, Drake, Future
# 564                         Pia Mia, Chris Brown, Tyga
# 571                                   GRiZ, Subtronics
# 577                                   Peachy!, mxmtoon
# 579                         Frank Sinatra, Count Basie
# 581                       The Gregory Brothers, TomSka
# 587                                      Riton, Kah-Lo
# 588                                     Valee, Jeremih
# 589               Anthony Gonzalez, Gael Garcia Bernal
# 593                              ilyTOMMY, Savage Ga$p
# 603  Jon Eidson, Evan Todd, Barrett Wilbert Weed, J...
# 604                             NextYoungin, ppcocaine
# 607  Christopher Fitzgerald, Kimiko Glenn, Waitress...
# 608                      Jowell & Randy, Kiko el Crazy
# 609                             Naughty Boy, Sam Smith
# 614                           Kardinal Offishall, Akon
# 620               Far East Movement, The Cataracs, DEV
# 625                                Clairo, Rejjie Snow
# 627                      Cast - Sofia the First, Sofia
#
#                                             track_name  \
# 4                                                 Tutu
# 6                     death bed (coffee for your head)
# 41                                  Deep End Freestyle
# 57                                              Lalala
# 58                                              Lalala
# 72                                            Go Crazy
# 113                   Savage Love (Laxed - Siren Beat)
# 114                   Savage Love (Laxed - Siren Beat)
# 166                                              Rodeo
# 171                                             Indigo
# 175                                 Never Ending Story
# 181                                              Juicy
# 217                                         Trampoline
# 233                                 Bored In The House
# 266                                            Bad Boy
# 277                                               Coño
# 286                                               Baby
# 314                                             Let Go
# 374                       Savage Remix (feat. Beyoncé)
# 376                                       Lose Control
# 389                        OUT WEST (feat. Young Thug)
# 390   Go Stupid (feat. NLE Choppa & Mike WiLL Made-It)
# 402                       Somebody That I Used To Know
# 419                                          You Right
# 444                                Leave The Door Open
# 445                                           Rasputin
# 450                                   Calling My Phone
# 461                                        Money Trees
# 467                                           Lemonade
# 533                                      We Found Love
# 542                                       American Boy
# 543                                       American Boy
# 544                                             No Lie
# 548                                             Middle
# 549                                    What's My Name?
# 552                                            Dilemma
# 557                                            Love Me
# 564                                        Do It Again
# 571                                        Griztronics
# 577                                      Falling for U
# 579                Fly Me To The Moon (In Other Words)
# 581                        The Muffin Song (asdfmovie)
# 587                                            Fake ID
# 588                                          Womp Womp
# 589                                       Un Poco Loco
# 593                                     Tunnel of Love
# 603                                            Big Fun
# 604                                       3 Musketeers
# 607                       Never Ever Getting Rid of Me
# 608                             Se Acabó la Cuarentena
# 609                                           La La La
# 614                                          Dangerous
# 620                                          Like A G6
# 625                                             Hello?
# 627  Sofia the First Main Title Theme - From "Sofia...
#
#                 artist_name  match  match_2
# 4                    Camilo  False     True
# 6                     Powfu  False     True
# 41            Sleepy Hallow  False     True
# 57                      Y2K  False     True
# 58                      Y2K  False     True
# 72              Chris Brown  False     True
# 113               Jawsh 685  False     True
# 114               Jawsh 685  False     True
# 166               Lil Nas X  False     True
# 171                88rising  False     True
# 175         Gaten Matarazzo  False     True
# 181                Doja Cat  False     True
# 217                   SHAED  False     True
# 233                    Tyga  False     True
# 266                Yung Bae  False     True
# 277                    Puri  False     True
# 286           Justin Bieber  False     True
# 314              Ark Patrol  False     True
# 374     Megan Thee Stallion  False     True
# 376                  MEDUZA  False     True
# 389                JACKBOYS  False     True
# 390                  Polo G  False     True
# 402                   Gotye  False     True
# 419                Doja Cat  False     True
# 444              Bruno Mars  False     True
# 445                Boney M.  False     True
# 450                Lil Tjay  False     True
# 461          Kendrick Lamar  False     True
# 467          Internet Money  False     True
# 533                 Rihanna  False     True
# 542                 Estelle  False     True
# 543                 Estelle  False     True
# 544               Sean Paul  False     True
# 548                DJ Snake  False     True
# 549                 Rihanna  False     True
# 552                   Nelly  False     True
# 557               Lil Wayne  False     True
# 564                 Pia Mia  False     True
# 571                    GRiZ  False     True
# 577                 Peachy!  False     True
# 579           Frank Sinatra  False     True
# 581    The Gregory Brothers  False     True
# 587                   Riton  False     True
# 588                   Valee  False     True
# 589        Anthony Gonzalez  False     True
# 593                ilyTOMMY  False     True
# 603              Jon Eidson  False     True
# 604             NextYoungin  False     True
# 607  Christopher Fitzgerald  False     True
# 608          Jowell & Randy  False     True
# 609             Naughty Boy  False     True
# 614      Kardinal Offishall  False     True
# 620       Far East Movement  False     True
# 625                  Clairo  False     True
# 627  Cast - Sofia the First  False     True

# %%
# Create a dataframe of overlapping songs based on the two matches colums and drop duplicates
df_tiktok_matches_final = df_tiktok_tracks_only.loc[(df_tiktok_tracks_only['match'] |df_tiktok_tracks_only['match_2'])]

# Check the shape of the df 
df_tiktok_matches_final.shape[0]
# Out:
# 422

# %%
# spot check an artist to see if the name matching looks appropriate 
df_tiktok_matches_final.loc[(df_tiktok_matches_final['artist_name'] == "Justin Bieber" )|( df_tiktok_matches_final['artist'] == "Justin Bieber" )]
# Out:
#                                       title                   artist  \
# 158                                 Hold On            Justin Bieber
# 174                                   Ghost            Justin Bieber
# 244                                    Baby  Justin Bieber, Ludacris
# 366  Peaches (feat. Daniel Caesar & Giveon)            Justin Bieber
#
#                                  track_name    artist_name  match  match_2
# 158                                 Hold On  Justin Bieber   True     True
# 174                                   Ghost  Justin Bieber   True     True
# 244                                    Baby  Justin Bieber  False     True
# 366  Peaches (feat. Daniel Caesar & Giveon)  Justin Bieber   True     True

# %%
# drop rows that are no longer needed
df_tiktok_matches_final.drop(['match', 'match_2', 'track_name', 'artist_name'], inplace =True, axis =1)

# add a column to indicate tiktok popularity 
df_tiktok_matches_final= df_tiktok_matches_final.assign(tiktok_pop = 1)

# %%
df_tiktok_matches_final.head()
# Out:
#                               title              artist  tiktok_pop
# 0                           Ride It              Regard           1
# 1                             GOOBA             6ix9ine           1
# 2                   Don't Start Now            Dua Lipa           1
# 3                              Tutu  Camilo, Pedro Capó           1
# 5  death bed (coffee for your head)  Powfu, beabadoobee           1

# %%
df_tiktok_matches_final.groupby(['tiktok_pop']).count()
# Out:
#             title  artist
# tiktok_pop
# 1             422     422

# %% [markdown]
# # Genius Lyrics Dataset Creation and EDA
